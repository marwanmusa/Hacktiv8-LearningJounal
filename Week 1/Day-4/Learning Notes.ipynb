# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('dataset/Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('dataset/ref.csv', sep = ';') #we can use sep or delimiter
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
df = pd.read_csv('dataset/nbaallelo.csv')

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.column", None)

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311  60.010067    GSW   Warriors      104  1809.9791  1813.6349
# 126312  59.290245    GSW   Warriors      105  1813.6349  1822.2881
# 126313  68.519516    CLE  Cavaliers       97  1700.7391  1692.0859
#
#        game_location game_result  forecast notes
# 126311             A           L  0.234435   NaN
# ...

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 97811       48906  200405070DET   NBA        1     2004   5/7/2004
# 125600      62801  201503110MIA   NBA        1     2015  3/11/2015
# 33092       16547  197503020BOS   NBA        1     1975   3/2/1975
# 34845       17423  197601200KEN   ABA        0     1976  1/20/1976
# 99782       49892  200503160LAC   NBA        1     2005  3/16/2005
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# 97811           88            1     NJN      Nets   80  1549.1964  1544.5990
# 125600          63            0     BRK      Nets   98  1430.0823  1425.4293
# 33092           65            0     SEA   Thunder  104  1435.7458  1455.1285
# 34845           42            0     KEN  Colonels  118  1582.7424  1588.0841
# 99782           64            0     ORL     Magic  102  1416.0059  1411.2944
#
#         win_equiv opp_id  opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %% [markdown]
# ### **Data Overview**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Berdasarkan overview, diperoleh :
# - dategame bisa diubah format nya ke date format
# - terdapat banyak data missing valus di column notes
# - ada anomaly di column pts

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %%
df['team_id'].unique()
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df['team_id'].value_counts().head(3)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head(3)
# Out:
# Lakers     6024
# Celtics    5997
# Knicks     5769
# Name: fran_id, dtype: int64

# %% [markdown]
# Hmm there is inconsistency...

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.loc[df['fran_id']=='Lakers',:]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.loc[df['fran_id']=='Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
5078+946
# Out:
# 6024

# %% [markdown]
# it look likes Lakers had 2 team id ...

# %%
# .loc with multiple columns
df.loc[df['fran_id']=='Lakers',
       ['year_id','team_id','fran_id','pts','opp_pts','opp_fran','opp_id']]
# Out:
#         year_id team_id fran_id  pts  opp_pts      opp_fran opp_id
# 1136       1949     MNL  Lakers   84       72     Baltimore    BLB
# 1152       1949     MNL  Lakers   62       67      Capitols    WSC
# 1159       1949     MNL  Lakers   55       77       Celtics    BOS
# 1170       1949     MNL  Lakers   77       68        Knicks    NYK
# 1183       1949     MNL  Lakers   90       67  Steamrollers    PRO
# ...         ...     ...     ...  ...      ...           ...    ...
# 126016     2015     LAL  Lakers  101      119       Nuggets    DEN
# 126052     2015     LAL  Lakers  106       98  Timberwolves    MIN
# 126086     2015     LAL  Lakers  106      120     Mavericks    DAL
# 126115     2015     LAL  Lakers   92      102         Kings    SAC
# 126137     2015     LAL  Lakers   99      122         Kings    SAC
#
# [6024 rows x 7 columns]

# %%
df.loc[(df['fran_id']=='Lakers')&(df['team_id']=='MNL'), :].tail()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 9701       4851  196003190LAL   NBA        0     1960  3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960  3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960  3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960  3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960  3/26/1960          84
#
#       is_playoffs team_id fran_id  pts      elo_i      elo_n  win_equiv  \
# 9701            1     MNL  Lakers   89  1471.0741  1464.6069  36.052319
# 9702            1     MNL  Lakers  103  1464.6069  1469.5608  36.565147
# 9709            1     MNL  Lakers  117  1469.5608  1484.6693  38.137211
# 9711            1     MNL  Lakers   96  1484.6693  1465.5942  36.154404
# 9715            1     MNL  Lakers   86  1465.5942  1461.1439  35.694744
#
# ...

# %%
df.loc[(df['fran_id']=='Lakers')&(df['team_id']=='LAL'), :].head()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 9730       4866  196010190CIN   NBA        1     1961  10/19/1960           1
# 9739       4870  196010220STL   NBA        1     1961  10/22/1960           2
# 9744       4873  196010240LAL   NBA        0     1961  10/24/1960           3
# 9747       4874  196010250LAL   NBA        0     1961  10/25/1960           4
# 9756       4879  196010280GSW   NBA        1     1961  10/28/1960           5
#
#       is_playoffs team_id fran_id  pts      elo_i      elo_n  win_equiv  \
# 9730            0     LAL  Lakers  123  1472.1079  1456.2350  35.369419
# 9739            0     LAL  Lakers   96  1456.2350  1450.4137  34.771576
# 9744            0     LAL  Lakers  101  1450.4137  1435.3485  33.237518
# 9747            0     LAL  Lakers  120  1435.3485  1438.7944  33.586594
# 9756            0     LAL  Lakers  120  1438.7944  1437.4066  33.445869
#
# ...

# %%
df.loc[(df['fran_id']=='Lakers')&(df['team_id']=='LAL'),'pts'].mean()
# Out:
# 108.15576998818432

# %%
df.loc[(df['fran_id']=='Lakers')&(df['team_id']=='LAL'),['year_id','pts']].min()
# Out:
# year_id    1961
# pts          68
# dtype: int64

# %% [markdown]
# ### **QUERY**

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df[
    (df['year_id'] > 2010) &
    (df['game_location'] == 'H') &
    (df['fran_id'] == 'Warriors') &
    (df['pts'] > 100)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# 113700      56851  201010290GSW   NBA        0     2011  10/29/2010
# 113767      56884  201011030GSW   NBA        0     2011   11/3/2010
# 113944      56973  201011150GSW   NBA        0     2011  11/15/2010
# 113998      57000  201011190GSW   NBA        0     2011  11/19/2010
# ...           ...           ...   ...      ...      ...         ...
# 126237      63119  201505030GSW   NBA        0     2015    5/3/2015
# 126284      63143  201505190GSW   NBA        0     2015   5/19/2015
# 126301      63151  201505270GSW   NBA        0     2015   5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015    6/4/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# ...

# %%
df[
    (df['year_id'] > 2010) &
    (df['game_location'] == 'H') &
    (df['fran_id'] == 'Warriors') &
    (df['pts'] > 100)
][['year_id','seasongame','fran_id']]
# Out:
#         year_id  seasongame   fran_id
# 113668     2011           1  Warriors
# 113700     2011           2  Warriors
# 113767     2011           4  Warriors
# 113944     2011          11  Warriors
# 113998     2011          12  Warriors
# ...         ...         ...       ...
# 126237     2015          87  Warriors
# 126284     2015          93  Warriors
# 126301     2015          97  Warriors
# 126303     2015          98  Warriors
# 126310     2015         102  Warriors
#
# [144 rows x 3 columns]

# %%
df[
    (df['year_id'] >= 2005) &
    (df['year_id'] <= 2012) &
    (df['seasongame'] % 2 == 1) &
    (df['game_result'] == 'W') &
    (df['pts'] > 80)
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 97887       48944  200411020DAL   NBA        0     2005  11/2/2004
# 97889       48945  200411020DET   NBA        0     2005  11/2/2004
# 97890       48946  200411020LAL   NBA        0     2005  11/2/2004
# 97893       48947  200411030BOS   NBA        1     2005  11/3/2004
# 97895       48948  200411030CLE   NBA        1     2005  11/3/2004
# ...           ...           ...   ...      ...      ...        ...
# 118405      59203  201206030BOS   NBA        0     2012   6/3/2012
# 118411      59206  201206060OKC   NBA        0     2012   6/6/2012
# 118412      59207  201206070BOS   NBA        1     2012   6/7/2012
# 118421      59211  201206170MIA   NBA        0     2012  6/17/2012
# 118424      59213  201206210MIA   NBA        0     2012  6/21/2012
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 97887            1            0     DAL  Mavericks  107  1595.4857  1602.0510
# ...

# %%
df[
    (df['year_id'] >= 2005) &
    (df['year_id'] <= 2012) &
    (df['seasongame'] % 2 == 1) &
    (df['game_result'] == 'W') &
    (df['pts'] > 80)
].shape
# Out:
# (5169, 23)

# %%
df.query("year_id >= 2005 & \
    year_id <= 2012 & \
    seasongame % 2 == 1 & \
    game_result == 'W' & \
    pts > 80")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 97887       48944  200411020DAL   NBA        0     2005  11/2/2004
# 97889       48945  200411020DET   NBA        0     2005  11/2/2004
# 97890       48946  200411020LAL   NBA        0     2005  11/2/2004
# 97893       48947  200411030BOS   NBA        1     2005  11/3/2004
# 97895       48948  200411030CLE   NBA        1     2005  11/3/2004
# ...           ...           ...   ...      ...      ...        ...
# 118405      59203  201206030BOS   NBA        0     2012   6/3/2012
# 118411      59206  201206060OKC   NBA        0     2012   6/6/2012
# 118412      59207  201206070BOS   NBA        1     2012   6/7/2012
# 118421      59211  201206170MIA   NBA        0     2012  6/17/2012
# 118424      59213  201206210MIA   NBA        0     2012  6/21/2012
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 97887            1            0     DAL  Mavericks  107  1595.4857  1602.0510
# ...

# %% [markdown]
# ### **Grouping and Aggregating**

# %%
df.groupby(by='fran_id')[['pts']].mean().sort_values(by='pts', ascending=False).head()
# Out:
#                    pts
# fran_id
# Condors     115.446512
# Squires     114.051314
# Floridians  112.654545
# Stars       112.354497
# Colonels    111.625296

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.game_location.value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
df.groupby(by='game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
#computing process
grup = df.groupby(by='game_location')
grup

# %%
grup.get_group('A')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 1                1            0     NYK     Knicks   68  1300.0000  1306.7233
# ...

# %%
grup.get_group('H')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 0                1            0     TRH       Huskies   66  1300.0000
# ...

# %%
grup.get_group('N')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 64302       32152  199011020UTA   NBA        1     1991   11/2/1990
# 64303       32152  199011020UTA   NBA        0     1991   11/2/1990
# 64318       32160  199011030PHO   NBA        1     1991   11/3/1990
# 64319       32160  199011030PHO   NBA        0     1991   11/3/1990
# 69000       34501  199211060HOU   NBA        0     1993   11/6/1992
# 69001       34501  199211060HOU   NBA        1     1993   11/6/1992
# 69030       34516  199211070SEA   NBA        1     1993   11/7/1992
# 69031       34516  199211070SEA   NBA        0     1993   11/7/1992
# 73736       36869  199411040LAC   NBA        0     1995   11/4/1994
# 73737       36869  199411040LAC   NBA        1     1995   11/4/1994
# 73766       36884  199411050POR   NBA        1     1995   11/5/1994
# 73767       36884  199411050POR   NBA        0     1995   11/5/1994
# 78694       39348  199611070NJN   NBA        1     1997   11/7/1996
# ...

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group('N')['pts'].mean()
# Out:
# 104.3157894736842

# %%
df[(df['year_id'] >= 2002) &
   (df['year_id'] <= 2015) &
   (df['fran_id'] == 'Celtics') &
   (df['opp_fran'] == 'Warriors') 
].groupby(by=['game_location','game_result'])[['pts']].mean()
# Out:
#                                   pts
# game_location game_result
# A             L             98.600000
#               W            111.250000
# H             L             94.750000
#               W            104.444444

# %% [markdown]
# H2H Celtics avg points vs Warriors from 2002 to 2015

# %% [markdown]
# ### Columns Manipulation
# - Rename Column
# - Drop Column
# - Create New Column

# %%
nba = df.copy()

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#rename
nba.rename(columns={'game_location':'loc', 'game_result':'result'}, inplace=True) #inplace=True to rename the data frame

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
#drop column
nba.drop(labels=['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n'], axis=1, inplace=True)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
#create new column
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts loc  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68   H
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66   A
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47   H
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63   A
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50   H
#
#   result  forecast notes
# 0      L  0.640065   NaN
# ...

# %%
nba['pts_diff'] = nba['pts'] - nba['opp_pts']

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'win_equiv',
#        'opp_id', 'opp_fran', 'opp_pts', 'loc', 'result', 'forecast', 'notes',
#        'pts_diff'],
#       dtype='object')

# %% [markdown]
# ### **Exercise**

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts loc  \
# 0            0     TRH  Huskies   66  40.294830    NYK    Knicks       68   H
# 1            0     NYK   Knicks   68  41.705170    TRH   Huskies       66   A
# 2            0     CHS    Stags   63  42.012257    NYK    Knicks       47   H
# 3            0     NYK   Knicks   47  40.692783    CHS     Stags       63   A
# 4            0     DTF  Falcons   33  38.864048    WSC  Capitols       50   H
#
#   result  forecast notes  pts_diff
# ...

# %%
# siapkan list kosong
# definisikan args dari for loop
# simpan hasil ke salam list kosong
# jika sudah selesai convert list menjadi kolom
# kolom pts -> nba.iloc[:, 10]
# kolom opp_pts -> nba.iloc[:, 14]

hasil =  []
for idx in range(0,len(nba)):
    selisih = nba.iloc[idx, 10] - nba.iloc[idx, 14]
    hasil.append(selisih)

hasil
# Out:
# [-2,
#  2,
#  16,
#  -16,
#  -17,
#  17,
#  -6,
#  6,
#  -5,
#  5,
#  -11,
#  11,
#  -15,
#  15,
#  -2,
#  2,
#  4,
#  -4,
#  -6,
#  6,
#  8,
#  -8,
#  -5,
#  5,
#  2,
#  -2,
#  -8,
#  8,
#  -23,
#  23,
#  10,
#  -10,
#  1,
#  -1,
#  24,
#  -24,
#  10,
#  -10,
#  13,
#  -13,
#  -10,
#  10,
#  -2,
#  2,
#  3,
#  -3,
#  -2,
#  2,
#  -17,
#  17,
#  -4,
#  4,
#  8,
#  -8,
#  2,
#  -2,
#  11,
#  -11,
#  9,
#  -9,
#  -2,
#  2,
#  4,
#  -4,
#  -6,
#  6,
#  -3,
#  3,
#  2,
#  -2,
#  1,
#  -1,
#  3,
#  -3,
#  3,
#  -3,
#  -12,
#  12,
#  -2,
#  2,
#  8,
#  -8,
#  -1,
#  1,
#  -8,
#  8,
#  -6,
#  6,
#  -6,
#  6,
#  24,
#  -24,
#  -13,
#  13,
#  -2,
#  2,
#  12,
#  -12,
#  16,
#  -16,
#  20,
#  -20,
#  12,
#  -12,
#  -10,
#  10,
#  -7,
#  7,
#  -2,
#  2,
#  8,
#  -8,
#  -4,
#  4,
#  3,
#  -3,
#  -13,
#  13,
#  -2,
#  2,
#  -15,
#  15,
#  4,
#  -4,
#  -14,
#  14,
#  3,
#  -3,
#  9,
#  -9,
#  -10,
#  10,
#  -2,
#  2,
#  -2,
#  2,
#  -8,
#  8,
#  -13,
#  13,
#  11,
#  -11,
#  18,
#  -18,
#  -4,
# ...

# %%
nba['pts_substract'] = hasil

# %% [markdown]
# ### **Visualization**

# %%
nba['fran_id'].value_counts().head(5).plot()
# Out:
# <AxesSubplot:>
